# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load the diabetes dataset (a well-known built-in dataset)
data = datasets.load_diabetes()

X = data.data[:, [2,3]]

X_train, X_test, y_train, y_test = train_test_split(X, data.target, test_size=0.2, random_state=0)
regr = LinearRegression()

regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))

plt.scatter(X_test[:, 0], y_test, color='black', label="Actual BMI")
plt.plot(X_test[:, 0], y_pred, color='blue', label="Predicted BMI")
plt.xlabel("BMI")
plt.ylabel("Diabetes Regression")
plt.title("Linear Regression with BMI and Blood Pressure")
plt.legend()
plt.show()
# Out:
# Coefficients:
#  [830.49125684 384.39276869]
# Mean squared error: 3701.79
# Coefficient of determination: 0.28
